# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'svg' # For mac users with Retina display

import os, sys
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from plotter import make_plot
import experiments as exp
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Let's make the Snowmass summary plot

# %%
make_plot('all', lsep=250, )
plt.text(10, 7e-5,r'$r=0.01$', rotation=38, color='grey', size=10)
# Out:
# Plotting experiments: ['ACTpol' 'BK18' 'POLARBEAR17' 'POLARBEAR22' 'Planck' 'SPT3G' 'SPTSZ'
#  'SPTpol']
# Text(10, 7e-05, '$r=0.01$')

# %% [markdown]
# ### BB from the ground

# %%
make_plot('ground', cmbs='BB',lsep=250, ylim=[1e-4,1])
plt.text(110, 2e-4,r'$r=0.01$', rotation=-60, color='grey', size=10)
plt.text(3, 0.5,r'BICEP/Keck',  color=exp.BK18().color, size=14)
plt.text(3, 0.2,r'POLARBEAR',  color=exp.POLARBEAR17().color, size=14)
plt.text(3, 0.09,r'SPT',  color=exp.SPTpol().color, size=14)
# Out:
# Plotting experiments: ['ACTpol' 'BK18' 'POLARBEAR17' 'POLARBEAR22' 'SPT3G' 'SPTSZ' 'SPTpol']
# Text(3, 0.09, 'SPT')

# %%
make_plot('ground', cmbs='BB',lsep=250, ylim=[1e-4,1],theory='camb')
plt.text(110, 2e-4,r'$r=0.01$', rotation=-60, color='grey', size=10)
plt.text(3, 0.5,r'BICEP/Keck',  color=exp.BK18().color, size=14)
plt.text(3, 0.2,r'POLARBEAR',  color=exp.POLARBEAR17().color, size=14)
plt.text(3, 0.09,r'SPT',  color=exp.SPTpol().color, size=14)
# Out:
# Plotting experiments: ['ACTpol' 'BK18' 'POLARBEAR17' 'POLARBEAR22' 'SPT3G' 'SPTSZ' 'SPTpol']
# Text(3, 0.09, 'SPT')

# %%
make_plot('ground', cmbs='TE',lsep=250, yscale='linear')
# Out:
# Plotting experiments: ['ACTpol' 'BK18' 'POLARBEAR17' 'POLARBEAR22' 'SPT3G' 'SPTSZ' 'SPTpol']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-fe5cab903d5e> in <module>
# ----> 1 make_plot('ground', cmbs='TE',lsep=250, yscale='linear')
#
# ~/Research/cmb_state_of_art/plotter.py in make_plot(exps, cmbs, xscaleL, xscaleR, yscale, nsigma, sigma_det, theory, lsep, datams, upperlimitms, error_lw, txtsize, theorycolor, theorylw, theoryls, cutsom_style, labsize, ylim, **kwargs)
#     158
#     159         # Plotting the theory
# --> 160         axL.plot(l_th, dl_lens[cmb], color=theorycolor[cmb], lw=theorylw[cmb], ls=theoryls[cmb])
#     161         axL.plot(l_th, dl_lens[cmb], color=theorycolor[cmb], lw=theorylw[cmb], ls=theoryls[cmb])
#     162
#
# KeyError: 'TE'
